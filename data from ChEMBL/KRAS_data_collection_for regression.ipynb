# %%
import pandas as pd
from rdkit import Chem
from chembl_webresource_client.new_client import new_client
from rdkit.Chem import PandasTools
from IPython.display import HTML

# %% [markdown]
# # Search for Target protein

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id='CHEMBL2189121').filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1069  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1070  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1071  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1072  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1073  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0        13352855                                                 []
# 1        13352856                                                 []
# 2        14548911                                                 []
# 3        14548912                                                 []
# 4        14548913                                                 []
# ...           ...                                                ...
# 1069     25727324  [{'comments': None, 'relation': '=', 'result_f...
# 1070     25727325  [{'comments': None, 'relation': '=', 'result_f...
# 1071     25727326  [{'comments': None, 'relation': '=', 'result_f...
# 1072     25727327  [{'comments': None, 'relation': '=', 'result_f...
# 1073     25727328  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL2399318  Inhibition of full-length human KRas4B (amino ...
# 1      CHEMBL2399319  Inhibition of full-length human KRas4B (amino ...
# 2      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# 3      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# 4      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# ...              ...                                                ...
# 1069   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1070   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1071   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1072   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1073   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                  P01116                   G12V  BAO_0000190
# 3             B                  P01116                   G12V  BAO_0000190
# 4             B                  P01116                   G12V  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1069          B                    None                   None  BAO_0000190
# 1070          B                    None                   None  BAO_0000190
# 1071          B                    None                   None  BAO_0000190
# 1072          B                    None                   None  BAO_0000190
# 1073          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens      GTPase KRas          9606       None  None
# 1     ...    Homo sapiens      GTPase KRas          9606       None  None
# 2     ...    Homo sapiens      GTPase KRas          9606       None  None
# 3     ...    Homo sapiens      GTPase KRas          9606       None  None
# 4     ...    Homo sapiens      GTPase KRas          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 1069  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1070  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1071  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1072  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1073  ...    Homo sapiens      GTPase KRas          9606       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    uM  UO_0000065        None  155.0
# 1     IC50    uM  UO_0000065        None  342.0
# 2     IC50    uM  UO_0000065        None    1.2
# 3     IC50    uM  UO_0000065        None   10.0
# 4     IC50    uM  UO_0000065        None    1.8
# ...    ...   ...         ...         ...    ...
# 1069  IC50    nM  UO_0000065        None  17.21
# 1070  IC50    nM  UO_0000065        None  10.22
# 1071  IC50    nM  UO_0000065        None   20.3
# 1072  IC50    nM  UO_0000065        None  16.69
# 1073  IC50    nM  UO_0000065        None  18.51
#
# [1074 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %% [markdown]
# # Handling data

# %% [markdown]
# If any compounds has missing value for the standard_value column then drop it.

# %%
df2 = df[df.pchembl_value.notna()]
# df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# 5                                                  None             None
# 6                                                  None             None
# ...                                                 ...              ...
# 1069  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1070  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1071  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1072  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1073  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 2        14548911                                                 []
# 3        14548912                                                 []
# 4        14548913                                                 []
# 5        14548914                                                 []
# 6        14548915                                                 []
# ...           ...                                                ...
# 1069     25727324  [{'comments': None, 'relation': '=', 'result_f...
# 1070     25727325  [{'comments': None, 'relation': '=', 'result_f...
# 1071     25727326  [{'comments': None, 'relation': '=', 'result_f...
# 1072     25727327  [{'comments': None, 'relation': '=', 'result_f...
# 1073     25727328  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 2      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# 3      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# 4      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# 5      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# 6      CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
# ...              ...                                                ...
# 1069   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1070   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1071   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1072   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
# 1073   CHEMBL5392290  Inhibition of recombinant human GTP-bound KRAS...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 2             B                  P01116                   G12V  BAO_0000190
# 3             B                  P01116                   G12V  BAO_0000190
# 4             B                  P01116                   G12V  BAO_0000190
# 5             B                  P01116                   G12V  BAO_0000190
# 6             B                  P01116                   G12V  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1069          B                    None                   None  BAO_0000190
# 1070          B                    None                   None  BAO_0000190
# 1071          B                    None                   None  BAO_0000190
# 1072          B                    None                   None  BAO_0000190
# 1073          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 2     ...    Homo sapiens      GTPase KRas          9606       None  None
# 3     ...    Homo sapiens      GTPase KRas          9606       None  None
# 4     ...    Homo sapiens      GTPase KRas          9606       None  None
# 5     ...    Homo sapiens      GTPase KRas          9606       None  None
# 6     ...    Homo sapiens      GTPase KRas          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 1069  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1070  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1071  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1072  ...    Homo sapiens      GTPase KRas          9606       None  None
# 1073  ...    Homo sapiens      GTPase KRas          9606       None  None
#
#       type units    uo_units upper_value  value
# 2     IC50    uM  UO_0000065        None    1.2
# 3     IC50    uM  UO_0000065        None   10.0
# 4     IC50    uM  UO_0000065        None    1.8
# 5     IC50    uM  UO_0000065        None    0.2
# 6     IC50    uM  UO_0000065        None   10.0
# ...    ...   ...         ...         ...    ...
# 1069  IC50    nM  UO_0000065        None  17.21
# 1070  IC50    nM  UO_0000065        None  10.22
# 1071  IC50    nM  UO_0000065        None   20.3
# 1072  IC50    nM  UO_0000065        None  16.69
# 1073  IC50    nM  UO_0000065        None  18.51
#
# [849 rows x 46 columns]

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value','pchembl_value', 'document_chembl_id']

# %%
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 2         CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 3         CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 4         CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# 5         CHEMBL3218638  CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...
# 6         CHEMBL3218639  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ...                 ...                                                ...
# 1069      CHEMBL5081048  C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5C[C@H]6CC[C@@H...
# 1070      CHEMBL5417773  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 1071      CHEMBL5429156  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 1072      CHEMBL5398447  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 1073      CHEMBL5434863  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...
#
#      standard_value pchembl_value document_chembl_id
# 2            1200.0          5.92      CHEMBL3217533
# 3           10000.0          5.00      CHEMBL3217533
# 4            1800.0          5.75      CHEMBL3217533
# 5             200.0          6.70      CHEMBL3217533
# 6           10000.0          5.00      CHEMBL3217533
# ...             ...           ...                ...
# 1069          17.21          7.76      CHEMBL5390265
# 1070          10.22          7.99      CHEMBL5390265
# 1071           20.3          7.69      CHEMBL5390265
# 1072          16.69          7.78      CHEMBL5390265
# 1073          18.51          7.73      CHEMBL5390265
#
# [849 rows x 5 columns]

# %%
# def convert_smi_to_canon_smi(smi):
#     canon_smi = Chem.MolToSmiles(Chem.MolFromSmiles(smi),isomericSmiles = False)
#     return canon_smi

# %%
# df3["canonical_smiles"] = df3.apply(lambda x: convert_smi_to_canon_smi(x.canonical_smiles), axis=1)
# Out:
# C:\Users\ovtti\AppData\Local\Temp\ipykernel_15596\1623896662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["canonical_smiles"] = df3.apply(lambda x: convert_smi_to_canon_smi(x.canonical_smiles), axis=1)

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 2         CHEMBL3218635  CC(C)C1NC(=O)C(CC(N)=O)NC(=O)C(CCCNC(=N)N)NC(=...
# 3         CHEMBL3218636  CCCCC1NC(=O)C(Cc2ccc3ccccc3c2)NC(=O)C(Cc2ccc3c...
# 4         CHEMBL3218637  CC1(C)COC(=O)C(Cc2ccccc2)NC(=O)C(CCCNC(=N)N)NC...
# 5         CHEMBL3218638  CC(C)CC1NC(=O)C(CCCNC(=N)N)NC(=O)C(CCCNC(=N)N)...
# 6         CHEMBL3218639  CC1(C)COC(=O)C(Cc2ccccc2)NC(=O)C(CCCNC(=N)N)NC...
# ...                 ...                                                ...
# 1069      CHEMBL5081048  C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)n...
# 1070      CHEMBL5417773  [H]C([H])(Oc1nc(N2CC3CCC(C2)N3)c2cnc(-c3cc(O)c...
# 1071      CHEMBL5429156  [H]C([H])(Oc1nc(N2CC3CCC(C2)N3)c2cnc(-c3cccc4c...
# 1072      CHEMBL5398447  [H]C([H])(Oc1nc(N2CC3CCC(C2)N3)c2cnc(-c3cc(N)c...
# 1073      CHEMBL5434863  [H]C([H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(O)...
#
#      standard_value pchembl_value document_chembl_id
# 2            1200.0          5.92      CHEMBL3217533
# 3           10000.0          5.00      CHEMBL3217533
# 4            1800.0          5.75      CHEMBL3217533
# 5             200.0          6.70      CHEMBL3217533
# 6           10000.0          5.00      CHEMBL3217533
# ...             ...           ...                ...
# 1069          17.21          7.76      CHEMBL5390265
# 1070          10.22          7.99      CHEMBL5390265
# 1071           20.3          7.69      CHEMBL5390265
# 1072          16.69          7.78      CHEMBL5390265
# 1073          18.51          7.73      CHEMBL5390265
#
# [849 rows x 5 columns]

# %%
def convert_smi_to_inchi(smi):
    molecule = Chem.MolFromSmiles(smi)
    inchikey = str(Chem.MolToInchi(molecule))
    return inchikey

# %%
df3["inchi"] = df3.apply(lambda x: convert_smi_to_inchi(x.canonical_smiles), axis=1)
# Out:
# [16:58:48] WARNING: Charges were rearranged
#
# [16:58:48] WARNING: Charges were rearranged
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Charges were rearranged
#
# [16:58:48] WARNING: Charges were rearranged
#
# [16:58:48] WARNING: Charges were rearranged
#
# [16:58:48] WARNING: Charges were rearranged
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# [16:58:48] WARNING: Omitted undefined stereo
#
# C:\Users\ovtti\AppData\Local\Temp\ipykernel_15596\3519335754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["inchi"] = df3.apply(lambda x: convert_smi_to_inchi(x.canonical_smiles), axis=1)

# %%
df3
# Out:
#      level_0  index molecule_chembl_id  \
# 0          0      2      CHEMBL3218635
# 1          1      3      CHEMBL3218636
# 2          2      4      CHEMBL3218637
# 3          3      5      CHEMBL3218638
# 4          4      6      CHEMBL3218639
# ..       ...    ...                ...
# 844      844   1069      CHEMBL5081048
# 845      845   1070      CHEMBL5417773
# 846      846   1071      CHEMBL5429156
# 847      847   1072      CHEMBL5398447
# 848      848   1073      CHEMBL5434863
#
#                                       canonical_smiles standard_value  \
# 0    CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...         1200.0
# 1    CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...        10000.0
# 2    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...         1800.0
# 3    CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...          200.0
# 4    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...        10000.0
# ..                                                 ...            ...
# 844  C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5C[C@H]6CC[C@@H...          17.21
# 845  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          10.22
# 846  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...           20.3
# 847  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          16.69
# 848  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...          18.51
#
#      pchembl_value document_chembl_id  \
# 0             5.92      CHEMBL3217533
# 1             5.00      CHEMBL3217533
# 2             5.75      CHEMBL3217533
# 3             6.70      CHEMBL3217533
# 4             5.00      CHEMBL3217533
# ..             ...                ...
# 844           7.76      CHEMBL5390265
# 845           7.99      CHEMBL5390265
# 846           7.69      CHEMBL5390265
# 847           7.78      CHEMBL5390265
# 848           7.73      CHEMBL5390265
#
#                                                  inchi
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...
# ..                                                 ...
# 844  InChI=1S/C33H31F3N6O2/c1-2-23-26(35)7-4-18-10-...
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...
#
# [849 rows x 8 columns]

# %%
df3['pchembl_value'] = pd.to_numeric(df3['pchembl_value'], downcast="float")

# %%
mean_std = df3.groupby(['canonical_smiles'], as_index=False).agg({'pchembl_value':['mean','std']})
mean_std
# Out:
#                                       canonical_smiles pchembl_value
#                                                                 mean std
# 0    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C)(C5)N...          7.62 NaN
# 1    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)c...          6.36 NaN
# 2    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)c...          8.10 NaN
# 3    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)n...          9.22 NaN
# 4    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)n...          9.40 NaN
# ..                                                 ...           ...  ..
# 564  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          7.78 NaN
# 565  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          7.99 NaN
# 566  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          7.69 NaN
# 567  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...          7.73 NaN
# 568  [2H]C1([2H])Oc2ccc(F)c(F)c2-c2nc3c(cc2Cl)c(N2C...          9.29 NaN
#
# [569 rows x 3 columns]

# %%
# Fix the column names while preserving 'canonical_smiles'
new_columns = []
for col in mean_std.columns:
    if isinstance(col, tuple):
        if col[0] == 'canonical_smiles':
            new_columns.append('canonical_smiles')  # Keep the original name
        else:
            new_columns.append(f'{col[0]}_{col[1]}')
    else:
        new_columns.append(col)

mean_std.columns = new_columns

# %%
mean_std
# Out:
#                                       canonical_smiles  pchembl_value_mean  \
# 0    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C)(C5)N...                7.62
# 1    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)c...                6.36
# 2    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)c...                8.10
# 3    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)n...                9.22
# 4    C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)n...                9.40
# ..                                                 ...                 ...
# 564  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...                7.78
# 565  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...                7.99
# 566  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...                7.69
# 567  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...                7.73
# 568  [2H]C1([2H])Oc2ccc(F)c(F)c2-c2nc3c(cc2Cl)c(N2C...                9.29
#
#      pchembl_value_std
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 564                NaN
# 565                NaN
# 566                NaN
# 567                NaN
# 568                NaN
#
# [569 rows x 3 columns]

# %%
df4 = df3.merge(mean_std, on=['canonical_smiles'])

# %%
df4
# Out:
#      level_0  index molecule_chembl_id  \
# 0          0      2      CHEMBL3218635
# 1          1      3      CHEMBL3218636
# 2          2      4      CHEMBL3218637
# 3          3      5      CHEMBL3218638
# 4          4      6      CHEMBL3218639
# ..       ...    ...                ...
# 844      844   1069      CHEMBL5081048
# 845      845   1070      CHEMBL5417773
# 846      846   1071      CHEMBL5429156
# 847      847   1072      CHEMBL5398447
# 848      848   1073      CHEMBL5434863
#
#                                       canonical_smiles standard_value  \
# 0    CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...         1200.0
# 1    CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...        10000.0
# 2    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...         1800.0
# 3    CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...          200.0
# 4    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...        10000.0
# ..                                                 ...            ...
# 844  C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5C[C@H]6CC[C@@H...          17.21
# 845  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          10.22
# 846  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...           20.3
# 847  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          16.69
# 848  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...          18.51
#
#      pchembl_value document_chembl_id  \
# 0             5.92      CHEMBL3217533
# 1             5.00      CHEMBL3217533
# 2             5.75      CHEMBL3217533
# 3             6.70      CHEMBL3217533
# 4             5.00      CHEMBL3217533
# ..             ...                ...
# 844           7.76      CHEMBL5390265
# 845           7.99      CHEMBL5390265
# 846           7.69      CHEMBL5390265
# 847           7.78      CHEMBL5390265
# 848           7.73      CHEMBL5390265
#
#                                                  inchi  pchembl_value_mean  \
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...            5.920000
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...            5.000000
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...            5.750000
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...            6.700000
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...            5.000000
# ..                                                 ...                 ...
# 844  InChI=1S/C33H31F3N6O2/c1-2-23-26(35)7-4-18-10-...            8.253333
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...            7.990000
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...            7.690000
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...            7.780000
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...            7.730000
#
#      pchembl_value_std
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 844           0.471734
# 845                NaN
# 846                NaN
# 847                NaN
# 848                NaN
#
# [849 rows x 10 columns]

# %%
df4['pchembl_value_std'] = df4['pchembl_value_std']. fillna (0)

# %%
df2_nr = df4.drop_duplicates(subset='canonical_smiles', keep='first')
df2_nr
# Out:
#      level_0  index molecule_chembl_id  \
# 0          0      2      CHEMBL3218635
# 1          1      3      CHEMBL3218636
# 2          2      4      CHEMBL3218637
# 3          3      5      CHEMBL3218638
# 4          4      6      CHEMBL3218639
# ..       ...    ...                ...
# 822      822   1041      CHEMBL5408369
# 845      845   1070      CHEMBL5417773
# 846      846   1071      CHEMBL5429156
# 847      847   1072      CHEMBL5398447
# 848      848   1073      CHEMBL5434863
#
#                                       canonical_smiles standard_value  \
# 0    CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...         1200.0
# 1    CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...        10000.0
# 2    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...         1800.0
# 3    CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...          200.0
# 4    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...        10000.0
# ..                                                 ...            ...
# 822  N#Cc1c(N)sc2c(F)ccc(-c3c(C(F)(F)F)cc4c(N5CC6CC...           0.86
# 845  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          10.22
# 846  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...           20.3
# 847  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          16.69
# 848  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...          18.51
#
#      pchembl_value document_chembl_id  \
# 0             5.92      CHEMBL3217533
# 1             5.00      CHEMBL3217533
# 2             5.75      CHEMBL3217533
# 3             6.70      CHEMBL3217533
# 4             5.00      CHEMBL3217533
# ..             ...                ...
# 822           9.07      CHEMBL5370635
# 845           7.99      CHEMBL5390265
# 846           7.69      CHEMBL5390265
# 847           7.78      CHEMBL5390265
# 848           7.73      CHEMBL5390265
#
#                                                  inchi  pchembl_value_mean  \
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...                5.92
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...                5.00
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...                5.75
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...                6.70
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...                5.00
# ..                                                 ...                 ...
# 822  InChI=1S/C32H29F6N7OS/c33-15-9-31(6-1-7-45(31)...                8.72
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...                7.99
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...                7.69
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...                7.78
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...                7.73
#
#      pchembl_value_std
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# ..                 ...
# 822           0.331813
# 845           0.000000
# 846           0.000000
# 847           0.000000
# 848           0.000000
#
# [569 rows x 10 columns]

# %%
df2_nr
# Out:
#      level_0  index molecule_chembl_id  \
# 0          0      2      CHEMBL3218635
# 1          1      3      CHEMBL3218636
# 2          2      4      CHEMBL3218637
# 3          3      5      CHEMBL3218638
# 4          4      6      CHEMBL3218639
# ..       ...    ...                ...
# 822      822   1041      CHEMBL5408369
# 845      845   1070      CHEMBL5417773
# 846      846   1071      CHEMBL5429156
# 847      847   1072      CHEMBL5398447
# 848      848   1073      CHEMBL5434863
#
#                                       canonical_smiles standard_value  \
# 0    CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...         1200.0
# 1    CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...        10000.0
# 2    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...         1800.0
# 3    CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...          200.0
# 4    CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...        10000.0
# ..                                                 ...            ...
# 822  N#Cc1c(N)sc2c(F)ccc(-c3c(C(F)(F)F)cc4c(N5CC6CC...           0.86
# 845  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          10.22
# 846  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...           20.3
# 847  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...          16.69
# 848  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...          18.51
#
#      pchembl_value document_chembl_id  \
# 0             5.92      CHEMBL3217533
# 1             5.00      CHEMBL3217533
# 2             5.75      CHEMBL3217533
# 3             6.70      CHEMBL3217533
# 4             5.00      CHEMBL3217533
# ..             ...                ...
# 822           9.07      CHEMBL5370635
# 845           7.99      CHEMBL5390265
# 846           7.69      CHEMBL5390265
# 847           7.78      CHEMBL5390265
# 848           7.73      CHEMBL5390265
#
#                                                  inchi  pchembl_value_mean  \
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...                5.92
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...                5.00
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...                5.75
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...                6.70
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...                5.00
# ..                                                 ...                 ...
# 822  InChI=1S/C32H29F6N7OS/c33-15-9-31(6-1-7-45(31)...                8.72
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...                7.99
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...                7.69
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...                7.78
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...                7.73
#
#      pchembl_value_std
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# ..                 ...
# 822           0.331813
# 845           0.000000
# 846           0.000000
# 847           0.000000
# 848           0.000000
#
# [569 rows x 10 columns]

# %%
selection = ['molecule_chembl_id','canonical_smiles','pchembl_value_mean', 'pchembl_value_std', 'inchi']

# %%
df5=df2_nr[selection]
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 1        CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 2        CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# 3        CHEMBL3218638  CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...
# 4        CHEMBL3218639  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ..                 ...                                                ...
# 822      CHEMBL5408369  N#Cc1c(N)sc2c(F)ccc(-c3c(C(F)(F)F)cc4c(N5CC6CC...
# 845      CHEMBL5417773  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 846      CHEMBL5429156  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 847      CHEMBL5398447  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 848      CHEMBL5434863  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...
#
#      pchembl_value_mean  pchembl_value_std  \
# 0                  5.92           0.000000
# 1                  5.00           0.000000
# 2                  5.75           0.000000
# 3                  6.70           0.000000
# 4                  5.00           0.000000
# ..                  ...                ...
# 822                8.72           0.331813
# 845                7.99           0.000000
# 846                7.69           0.000000
# 847                7.78           0.000000
# 848                7.73           0.000000
#
#                                                  inchi
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...
# ..                                                 ...
# 822  InChI=1S/C32H29F6N7OS/c33-15-9-31(6-1-7-45(31)...
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...
#
# [569 rows x 5 columns]

# %%
def remove_salt(smi):
    if '.' in smi:
        smi='SALT_MIX'
    
    return smi

# %%
df5["canonical_smiles"] = df5.apply(lambda x: remove_salt(x.canonical_smiles), axis=1)
# Out:
# C:\Users\ovtti\AppData\Local\Temp\ipykernel_15596\3359572543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["canonical_smiles"] = df5.apply(lambda x: remove_salt(x.canonical_smiles), axis=1)

# %%
df6 = df5[(df5[('canonical_smiles')] != 'SALT_MIX')]

# %%
df6
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 1        CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 2        CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# 3        CHEMBL3218638  CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...
# 4        CHEMBL3218639  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ..                 ...                                                ...
# 822      CHEMBL5408369  N#Cc1c(N)sc2c(F)ccc(-c3c(C(F)(F)F)cc4c(N5CC6CC...
# 845      CHEMBL5417773  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 846      CHEMBL5429156  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 847      CHEMBL5398447  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 848      CHEMBL5434863  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...
#
#      pchembl_value_mean  pchembl_value_std  \
# 0                  5.92           0.000000
# 1                  5.00           0.000000
# 2                  5.75           0.000000
# 3                  6.70           0.000000
# 4                  5.00           0.000000
# ..                  ...                ...
# 822                8.72           0.331813
# 845                7.99           0.000000
# 846                7.69           0.000000
# 847                7.78           0.000000
# 848                7.73           0.000000
#
#                                                  inchi
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...
# ..                                                 ...
# 822  InChI=1S/C32H29F6N7OS/c33-15-9-31(6-1-7-45(31)...
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...
#
# [568 rows x 5 columns]

# %%
df6.sort_values(by='pchembl_value_std')
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 508      CHEMBL5078080  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 507      CHEMBL5082252  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 506      CHEMBL5088845  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 505      CHEMBL5082880  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# ..                 ...                                                ...
# 814      CHEMBL5418176  Nc1cc2ccccc2c(-c2c(Cl)cc3c(N4CC5CCC(C4)N5)nc(O...
# 307      CHEMBL4852058  Cc1ccnc(C(C)C)c1-n1c(=O)nc(N2CC(NC(=O)C3CO3)C2...
# 811      CHEMBL5418527  Cc1cc(N)nc(-c2c(Cl)cc3c(N4CC5CCC(C4)N5)nc(OC[C...
# 432      CHEMBL5075960  C=CC(=O)N1CC2(CC(n3nc(-c4ccc(N5CCC5=O)cc4)c(-c...
# 441      CHEMBL5085560  C=CC(=O)N1CC2(CC(n3nc(-c4ccc5c(c4)CCN5C(=O)CN4...
#
#      pchembl_value_mean  pchembl_value_std  \
# 0                 5.920           0.000000
# 508               4.000           0.000000
# 507               4.110           0.000000
# 506               4.310           0.000000
# 505               4.180           0.000000
# ..                  ...                ...
# 814               6.710           1.668772
# 307               6.555           1.689985
# 811               7.245           1.718269
# 432               6.195           1.944544
# 441               6.350           2.078894
#
#                                                  inchi
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...
# 508  InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-...
# 507  InChI=1S/C39H51N9O9/c1-23(2)17-28(35(40)52)43-...
# 506  InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-...
# 505  InChI=1S/C39H51N9O9/c1-23(2)17-28(35(40)52)43-...
# ..                                                 ...
# 814  InChI=1S/C31H32ClF2N7O/c32-23-11-22-28(26(34)2...
# 307  InChI=1S/C28H26ClFN6O3/c1-14(2)22-24(15(3)8-9-...
# 811  InChI=1S/C27H30ClF4N7O/c1-13-8-19(33)35-24(21(...
# 432  InChI=1S/C30H29ClN6O2/c1-4-24(38)35-15-30(16-3...
# 441  InChI=1S/C35H37ClFN7O2/c1-4-29(45)42-18-35(19-...
#
# [568 rows x 5 columns]

# %%
#keep only SD less thab 0.5 SD
df6 = df6[(df6['pchembl_value_std'] < 0.5)]
df6
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 1        CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 2        CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# 3        CHEMBL3218638  CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H...
# 4        CHEMBL3218639  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ..                 ...                                                ...
# 822      CHEMBL5408369  N#Cc1c(N)sc2c(F)ccc(-c3c(C(F)(F)F)cc4c(N5CC6CC...
# 845      CHEMBL5417773  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 846      CHEMBL5429156  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 847      CHEMBL5398447  [2H]C([2H])(Oc1nc(N2C[C@H]3CC[C@@H](C2)N3)c2cn...
# 848      CHEMBL5434863  [2H]C([2H])(Oc1nc(NCC2(N(C)C)CCC2)c2cnc(-c3cc(...
#
#      pchembl_value_mean  pchembl_value_std  \
# 0                  5.92           0.000000
# 1                  5.00           0.000000
# 2                  5.75           0.000000
# 3                  6.70           0.000000
# 4                  5.00           0.000000
# ..                  ...                ...
# 822                8.72           0.331813
# 845                7.99           0.000000
# 846                7.69           0.000000
# 847                7.78           0.000000
# 848                7.73           0.000000
#
#                                                  inchi
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...
# 1    InChI=1S/C81H103FN14O13/c1-4-5-24-63-79(108)10...
# 2    InChI=1S/C72H92N14O14/c1-72(2)43-100-70(99)57(...
# 3    InChI=1S/C70H102FN19O14/c1-40(2)35-53-66(103)1...
# 4    InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...
# ..                                                 ...
# 822  InChI=1S/C32H29F6N7OS/c33-15-9-31(6-1-7-45(31)...
# 845  InChI=1S/C34H30F4N6O2/c1-2-23-26(35)7-4-18-10-...
# 846  InChI=1S/C34H30F4N6O/c1-2-23-26(35)10-7-19-5-3...
# 847  InChI=1S/C34H31F4N7O/c1-2-23-26(35)7-4-18-10-2...
# 848  InChI=1S/C35H34F4N6O2/c1-4-23-26(36)8-7-20-13-...
#
# [488 rows x 5 columns]

# %%
df6.sort_values(by='pchembl_value_std')
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 579      CHEMBL5196734  C=CC(=O)N1CCN(c2nc(NC3CCN(C)CC3)nc3c(F)c(-c4c(...
# 526      CHEMBL5090997  CC(=O)N[C@@H](Cc1ccccc1)C(=O)N[C@@H](Cc1cnc[nH...
# 525      CHEMBL5079807  CC[C@@H](C)[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)[C@H]...
# 524      CHEMBL5085761  CC(=O)N[C@@H](CC(=O)O)C(=O)N[C@H]1CCCn2nncc2CO...
# ..                 ...                                                ...
# 462      CHEMBL5081048  C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5C[C@H]6CC[C@@H...
# 33       CHEMBL4070657  CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# 710      CHEMBL5269272  Oc1cc(-c2ncc3c(N4CCCC5(CCO5)C4)nc(OC[C@@]45CCC...
# 107      CHEMBL4464232  C=CC(=O)N1CCN(c2nc(=O)n(-c3c(C)cccc3CC)c3nc(-c...
# 28       CHEMBL4075783  CC(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](CCCNC(=N...
#
#      pchembl_value_mean  pchembl_value_std  \
# 0              5.920000           0.000000
# 579            6.330000           0.000000
# 526            5.480000           0.000000
# 525            5.070000           0.000000
# 524            4.400000           0.000000
# ..                  ...                ...
# 462            8.253333           0.471734
# 33             7.477500           0.474298
# 710            8.583333           0.485627
# 107            7.250000           0.494975
# 28             4.630000           0.495849
#
#                                                  inchi
# 0    InChI=1S/C67H94FN17O15/c1-37(2)54-64(99)100-36...
# 579  InChI=1S/C29H32ClFN8O/c1-4-23(40)38-11-13-39(1...
# 526  InChI=1S/C100H126N20O19/c1-58(2)43-74(90(128)1...
# 525  InChI=1S/C93H126N20O19/c1-9-55(6)80-91(129)107...
# 524  InChI=1S/C51H69N13O13/c1-28(2)21-36(46(71)55-2...
# ..                                                 ...
# 462  InChI=1S/C33H31F3N6O2/c1-2-23-26(35)7-4-18-10-...
# 33   InChI=1S/C106H178N44O25S2/c1-7-54(4)79-96(173)...
# 710  InChI=1S/C32H31F4N5O3/c33-19-13-31(5-1-9-41(31...
# 107  InChI=1S/C30H29ClFN5O3/c1-5-19-10-7-9-17(3)27(...
# 28   InChI=1S/C105H176N44O25S2/c1-52(2)45-68-89(166...
#
# [488 rows x 5 columns]

# %%
data=df6.drop(['pchembl_value_std' ], axis=1)

# %%
data.describe()
# Out:
#        pchembl_value_mean
# count          488.000000
# mean             6.515008
# std              1.358360
# min              3.810000
# 25%              5.517500
# 50%              6.360000
# 75%              7.542500
# max             10.000000

# %% [markdown]
# # Creating training and test samples

# %%
data=data.sort_values(by='pchembl_value_mean')
data
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 10       CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 497      CHEMBL5082248  NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H]1COCc2cnnn2C...
# 498      CHEMBL5079991  CCCC[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(...
# 492      CHEMBL5082312  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 476      CHEMBL5083076  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# ..                 ...                                                ...
# 419      CHEMBL4876040  C#Cc1cccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)nc(O...
# 423      CHEMBL4858364  C#Cc1c(F)ccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)n...
# 417      CHEMBL4863339  C#Cc1cccc2cc(O)cc(-c3ncc4c(N5CC6CCC(C5)N6)nc(O...
# 422      CHEMBL4857438  Oc1cc(-c2ncc3c(N4CC5CCC(C4)N5)nc(OC[C@@]45CCCN...
# 425      CHEMBL4855757  Oc1cc(-c2ncc3c(N4CC5CCC(C4)N5)nc(OCC45CCCN4C(C...
#
#      pchembl_value_mean                                              inchi
# 10                 3.81  InChI=1S/C11H12Cl2N2/c1-6-8(2-3-14)11-9(13)4-7...
# 497                4.00  InChI=1S/C40H53N9O7/c41-37(52)31(20-26-10-2-1-...
# 498                4.00  InChI=1S/C37H49N9O7/c1-2-3-14-28(34(38)49)41-3...
# 492                4.00  InChI=1S/C38H53N9O7/c1-23(2)17-29(35(39)50)42-...
# 476                4.00  InChI=1S/C33H53N9O7/c1-21(2)15-24(30(34)45)37-...
# ..                  ...                                                ...
# 419                9.40  InChI=1S/C33H32F2N6O2/c1-2-19-5-3-6-20-11-24(4...
# 423                9.40  InChI=1S/C33H31F3N6O2/c1-2-23-26(35)7-4-18-10-...
# 417                9.52  InChI=1S/C33H33FN6O2/c1-2-20-6-3-7-21-14-24(41...
# 422                9.70  InChI=1S/C31H31ClF2N6O2/c32-24-4-1-3-17-9-21(4...
# 425               10.00  InChI=1S/C32H34F2N6O2/c33-14-22-8-10-32(9-3-11...
#
# [488 rows x 4 columns]

# %%
data_test=data.loc[::5]
data_test.head(20)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 10       CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 473      CHEMBL5084686  CC[C@H](C)[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)CNC(=O...
# 523      CHEMBL5077657  CC(=O)N[C@@H](CCC(=O)O)C(=O)N[C@H]1CCCn2nncc2C...
# 490      CHEMBL5091680  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 484      CHEMBL5080225  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 500      CHEMBL5076240  NC(=O)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N...
# 524      CHEMBL5085761  CC(=O)N[C@@H](CC(=O)O)C(=O)N[C@H]1CCCn2nncc2CO...
# 264      CHEMBL4796065     CN(C)Cc1[nH]c2ccccc2c1[C@H]1NC(=O)c2ccc(O)cc21
# 499      CHEMBL5081269  NC(=O)[C@H](CC1CC1)NC(=O)[C@@H]1COCc2cnnn2CCCC...
# 504      CHEMBL5076675  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 480      CHEMBL5088241  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 677      CHEMBL5172544  C=CC(=O)N1CCN2c3ncnc4cc(-c5c(C)ccc6[nH]ncc56)c...
# 520      CHEMBL5087378  CC(C)C[C@H](NC(=O)[C@H]1CCn2nncc2CCCC(=O)NCC(=...
# 4        CHEMBL3218639  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# 509      CHEMBL5082155  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CC(=O)NCC(=...
# 258       CHEMBL187437         COc1ccc(C(=O)/C=C/c2cc(OC)c(OC)c(OC)c2)cc1
# 799      CHEMBL5434304  C=CC(=O)N1CCN(Cc2cc(F)c(-c3c(O)cccc3Cl)c(F)c2)CC1
# 259        CHEMBL62070        COc1cc(/C=C/C(=O)c2ccc(N(C)C)cc2)cc(OC)c1OC
# 340      CHEMBL4862158  C[C@@H]1NC(=O)[C@@H](Cc2ccccc2)NC(=O)[C@@H]2CC...
# 782      CHEMBL5411023  C=CC(=O)N1CCN2Cc3ccc(-c4c(C)ccc5[nH]ncc45)c(Cl...
#
#      pchembl_value_mean                                              inchi
# 10                3.810  InChI=1S/C11H12Cl2N2/c1-6-8(2-3-14)11-9(13)4-7...
# 473               4.000  InChI=1S/C30H49N9O7/c1-5-19(4)26-30(45)35-22(2...
# 523               4.030  InChI=1S/C44H59N11O11/c1-25(2)19-33(39(45)60)5...
# 490               4.160  InChI=1S/C37H49N9O8/c1-22(2)16-27(34(38)50)41-...
# 484               4.275  InChI=1S/C31H45N9O7S/c1-19(2)13-22(28(32)43)35...
# 500               4.315  InChI=1S/C35H44N10O8/c36-29(46)16-25(32(37)49)...
# 524               4.400  InChI=1S/C51H69N13O13/c1-28(2)21-36(46(71)55-2...
# 264               4.480  InChI=1S/C19H19N3O2/c1-22(2)10-16-17(13-5-3-4-...
# 499               4.540  InChI=1S/C37H47N9O7/c38-34(49)28(17-23-13-14-2...
# 504               4.600  InChI=1S/C38H51N9O7/c1-23(2)18-29(34(39)49)42-...
# 480               4.745  InChI=1S/C35H48N10O7/c1-21(2)14-26(32(36)48)40...
# 677               4.810  InChI=1S/C25H23ClN6O2/c1-3-20(33)31-7-8-32-15(...
# 520               4.895  InChI=1S/C36H47N9O6/c1-22(2)18-28(33(37)48)41-...
# 4                 5.000  InChI=1S/C75H93N13O15/c1-75(2)45-103-73(102)59...
# 509               5.020  InChI=1S/C34H43N9O7/c1-20(2)13-25(31(35)46)38-...
# 258               5.080  InChI=1S/C19H20O5/c1-21-15-8-6-14(7-9-15)16(20...
# 799               5.110  InChI=1S/C20H19ClF2N2O2/c1-2-18(27)25-8-6-24(7...
# 259               5.130  InChI=1S/C20H23NO4/c1-21(2)16-9-7-15(8-10-16)1...
# 340               5.160  InChI=1S/C111H146N32O24/c1-59-91(150)130-75(30...
# 782               5.240  InChI=1S/C24H25ClN4O2/c1-3-21(30)29-10-9-28-13...

# %%
data_work=data.drop(data.loc[::5].index)

# %%
data.head(30)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 10       CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 497      CHEMBL5082248  NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H]1COCc2cnnn2C...
# 498      CHEMBL5079991  CCCC[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(...
# 492      CHEMBL5082312  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 476      CHEMBL5083076  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 473      CHEMBL5084686  CC[C@H](C)[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)CNC(=O...
# 508      CHEMBL5078080  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 700      CHEMBL4293433          C=CC(=O)N1CCN(C(=O)CNc2cc(I)c(Cl)cc2O)CC1
# 474      CHEMBL5088053  C=C1/C=C/COC[C@@H](C(=O)N[C@@H](CC(C)C)C(N)=O)...
# 489      CHEMBL5078607  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 523      CHEMBL5077657  CC(=O)N[C@@H](CCC(=O)O)C(=O)N[C@H]1CCCn2nncc2C...
# 475      CHEMBL5081452  CC(C)C[C@H](CC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 514      CHEMBL5093669  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCCCCC(=O...
# 496      CHEMBL5086801  NC(=O)[C@@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N...
# 507      CHEMBL5082252  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 490      CHEMBL5091680  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 505      CHEMBL5082880  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 518      CHEMBL5076432  CC(C)C[C@H](NC(=O)[C@H]1Cc2cnnn2CCCCC(=O)NCC(=...
# 477      CHEMBL5087475  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 487      CHEMBL5081764  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 484      CHEMBL5080225  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 255      CHEMBL3219765               COc1cc(/C=C/C(=O)c2ccccn2)cc(OC)c1OC
# 701      CHEMBL5269554  C=CC(=O)N1CC(N2CCN(C(=O)CNc3cc(Cl)c(Cl)cc3O)CC...
# 501      CHEMBL5093615  NC(=O)CC[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)...
# 506      CHEMBL5088845  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 500      CHEMBL5076240  NC(=O)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N...
# 478      CHEMBL5084212  CCCC[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)CNC(=O)CCCCn...
# 512      CHEMBL5078981  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N2...
# 521      CHEMBL5075344  CC(C)C[C@H](NC(=O)[C@H]1COCc2cnnn2CCCCC(=O)NCC...
# 483      CHEMBL5083699  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
#
#      pchembl_value_mean                                              inchi
# 10                3.810  InChI=1S/C11H12Cl2N2/c1-6-8(2-3-14)11-9(13)4-7...
# 497               4.000  InChI=1S/C40H53N9O7/c41-37(52)31(20-26-10-2-1-...
# 498               4.000  InChI=1S/C37H49N9O7/c1-2-3-14-28(34(38)49)41-3...
# 492               4.000  InChI=1S/C38H53N9O7/c1-23(2)17-29(35(39)50)42-...
# 476               4.000  InChI=1S/C33H53N9O7/c1-21(2)15-24(30(34)45)37-...
# 473               4.000  InChI=1S/C30H49N9O7/c1-5-19(4)26-30(45)35-22(2...
# 508               4.000  InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-...
# 700               4.000  InChI=1S/C15H17ClIN3O3/c1-2-14(22)19-3-5-20(6-...
# 474               4.010  InChI=1S/C29H46N6O7/c1-6-19(5)25-29(41)33-21(2...
# 489               4.020  InChI=1S/C37H49N9O8/c1-22(2)14-28(34(38)50)41-...
# 523               4.030  InChI=1S/C44H59N11O11/c1-25(2)19-33(39(45)60)5...
# 475               4.040  InChI=1S/C30H46N6O7/c1-19(2)11-21(30(31)42)13-...
# 514               4.090  InChI=1S/C38H52N8O6/c1-25(2)20-30(35(39)48)41-...
# 496               4.110  InChI=1S/C39H51N9O7/c40-36(51)35(26-11-2-1-3-1...
# 507               4.110  InChI=1S/C39H51N9O9/c1-23(2)17-28(35(40)52)43-...
# 490               4.160  InChI=1S/C37H49N9O8/c1-22(2)16-27(34(38)50)41-...
# 505               4.180  InChI=1S/C39H51N9O9/c1-23(2)17-28(35(40)52)43-...
# 518               4.190  InChI=1S/C36H47N9O6/c1-22(2)17-27(33(37)48)40-...
# 477               4.220  InChI=1S/C30H49N9O7/c1-18(2)12-21(27(31)42)34-...
# 487               4.260  InChI=1S/C39H53N9O7/c1-25(2)19-30(36(40)51)43-...
# 484               4.275  InChI=1S/C31H45N9O7S/c1-19(2)13-22(28(32)43)35...
# 255               4.280  InChI=1S/C17H17NO4/c1-20-15-10-12(11-16(21-2)1...
# 701               4.300  InChI=1S/C18H22Cl2N4O3/c1-2-17(26)24-10-12(11-...
# 501               4.300  InChI=1S/C36H46N10O8/c37-30(47)14-13-26(33(38)...
# 506               4.310  InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-...
# 500               4.315  InChI=1S/C35H44N10O8/c36-29(46)16-25(32(37)49)...
# 478               4.320  InChI=1S/C30H49N9O7/c1-4-5-9-21-28(43)36-23(29...
# 512               4.320  InChI=1S/C35H46N8O6/c1-22(2)17-27(32(36)45)38-...
# 521               4.340  InChI=1S/C45H61N11O9/c1-27(2)21-33(41(60)49-28...
# 483               4.390  InChI=1S/C32H46N10O7/c1-20(2)13-23(29(33)45)37...

# %%
data_work.head(25)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 497      CHEMBL5082248  NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H]1COCc2cnnn2C...
# 498      CHEMBL5079991  CCCC[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(...
# 492      CHEMBL5082312  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 476      CHEMBL5083076  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 508      CHEMBL5078080  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 700      CHEMBL4293433          C=CC(=O)N1CCN(C(=O)CNc2cc(I)c(Cl)cc2O)CC1
# 474      CHEMBL5088053  C=C1/C=C/COC[C@@H](C(=O)N[C@@H](CC(C)C)C(N)=O)...
# 489      CHEMBL5078607  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 475      CHEMBL5081452  CC(C)C[C@H](CC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 514      CHEMBL5093669  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCCCCC(=O...
# 496      CHEMBL5086801  NC(=O)[C@@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N...
# 507      CHEMBL5082252  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 505      CHEMBL5082880  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 518      CHEMBL5076432  CC(C)C[C@H](NC(=O)[C@H]1Cc2cnnn2CCCCC(=O)NCC(=...
# 477      CHEMBL5087475  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 487      CHEMBL5081764  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 255      CHEMBL3219765               COc1cc(/C=C/C(=O)c2ccccn2)cc(OC)c1OC
# 701      CHEMBL5269554  C=CC(=O)N1CC(N2CCN(C(=O)CNc3cc(Cl)c(Cl)cc3O)CC...
# 501      CHEMBL5093615  NC(=O)CC[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)...
# 506      CHEMBL5088845  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[...
# 478      CHEMBL5084212  CCCC[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)CNC(=O)CCCCn...
# 512      CHEMBL5078981  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N2...
# 521      CHEMBL5075344  CC(C)C[C@H](NC(=O)[C@H]1COCc2cnnn2CCCCC(=O)NCC...
# 483      CHEMBL5083699  CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NC...
# 522      CHEMBL5081734  CC(=O)N[C@@H](CC(=O)O)C(=O)N[C@H]1CCCn2nncc2CO...
#
#      pchembl_value_mean                                              inchi
# 497                4.00  InChI=1S/C40H53N9O7/c41-37(52)31(20-26-10-2-1-...
# 498                4.00  InChI=1S/C37H49N9O7/c1-2-3-14-28(34(38)49)41-3...
# 492                4.00  InChI=1S/C38H53N9O7/c1-23(2)17-29(35(39)50)42-...
# 476                4.00  InChI=1S/C33H53N9O7/c1-21(2)15-24(30(34)45)37-...
# 508                4.00  InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-...
# 700                4.00  InChI=1S/C15H17ClIN3O3/c1-2-14(22)19-3-5-20(6-...
# 474                4.01  InChI=1S/C29H46N6O7/c1-6-19(5)25-29(41)33-21(2...
# 489                4.02  InChI=1S/C37H49N9O8/c1-22(2)14-28(34(38)50)41-...
# 475                4.04  InChI=1S/C30H46N6O7/c1-19(2)11-21(30(31)42)13-...
# 514                4.09  InChI=1S/C38H52N8O6/c1-25(2)20-30(35(39)48)41-...
# 496                4.11  InChI=1S/C39H51N9O7/c40-36(51)35(26-11-2-1-3-1...
# 507                4.11  InChI=1S/C39H51N9O9/c1-23(2)17-28(35(40)52)43-...
# 505                4.18  InChI=1S/C39H51N9O9/c1-23(2)17-28(35(40)52)43-...
# 518                4.19  InChI=1S/C36H47N9O6/c1-22(2)17-27(33(37)48)40-...
# 477                4.22  InChI=1S/C30H49N9O7/c1-18(2)12-21(27(31)42)34-...
# 487                4.26  InChI=1S/C39H53N9O7/c1-25(2)19-30(36(40)51)43-...
# 255                4.28  InChI=1S/C17H17NO4/c1-20-15-10-12(11-16(21-2)1...
# 701                4.30  InChI=1S/C18H22Cl2N4O3/c1-2-17(26)24-10-12(11-...
# 501                4.30  InChI=1S/C36H46N10O8/c37-30(47)14-13-26(33(38)...
# 506                4.31  InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-...
# 478                4.32  InChI=1S/C30H49N9O7/c1-4-5-9-21-28(43)36-23(29...
# 512                4.32  InChI=1S/C35H46N8O6/c1-22(2)17-27(32(36)45)38-...
# 521                4.34  InChI=1S/C45H61N11O9/c1-27(2)21-33(41(60)49-28...
# 483                4.39  InChI=1S/C32H46N10O7/c1-20(2)13-23(29(33)45)37...
# 522                4.42  InChI=1S/C43H57N11O11/c1-24(2)17-31(38(44)59)4...

# %% [markdown]
# # Creating sdf files

# %% [markdown]
# Creating test set

# %%
PandasTools.AddMoleculeColumnToFrame(data_test, 'canonical_smiles', 'Molecule')
# Out:
# C:\Users\ovtti\anaconda3\Lib\site-packages\rdkit\Chem\PandasTools.py:379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)

# %%
HTML(data_test.head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>molecule_chembl_id</th>
#       <th>canonical_smiles</th>
#       <th>pchembl_value_mean</th>
#       <th>inchi</th>
#       <th>Molecule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>CHEMBL2396992</td>
#       <td>Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN</td>
#       <td>3.810</td>
#       <td>InChI=1S/C11H12Cl2N2/c1-6-8(2-3-14)11-9(13)4-7(12)5-10(11)15-6/h4-5,15H,2-3,14H2,1H3</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B220209E0&gt;</td>
#     </tr>
#     <tr>
#       <th>473</th>
#       <td>CHEMBL5084686</td>
#       <td>CC[C@H](C)[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)CNC(=O)CCCCn2nncc2COC[C@@H](C(=O)N[C@@H](CC(C)C)C(N)=O)NC1=O</td>
#       <td>4.000</td>
#       <td>InChI=1S/C30H49N9O7/c1-5-19(4)26-30(45)35-22(28(43)34-21(27(31)42)13-18(2)3)17-46-16-20-14-33-37-39(20)12-7-6-10-24(40)32-15-25(41)38-11-8-9-23(38)29(44)36-26/h14,18-19,21-23,26H,5-13,15-17H2,1-4H3,(H2,31,42)(H,32,40)(H,34,43)(H,35,45)(H,36,44)/t19-,21-,22-,23-,26-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B22020200&gt;</td>
#     </tr>
#     <tr>
#       <th>523</th>
#       <td>CHEMBL5077657</td>
#       <td>CC(=O)N[C@@H](CCC(=O)O)C(=O)N[C@H]1CCCn2nncc2COC[C@H](C(=O)N[C@@H](CC(C)C)C(N)=O)NC(=O)[C@H](Cc2cccc3ccccc23)NC(=O)[C@@H]2CCCN2C(=O)CNC1=O</td>
#       <td>4.030</td>
#       <td>InChI=1S/C44H59N11O11/c1-25(2)19-33(39(45)60)50-43(64)35-24-66-23-29-21-47-53-55(29)18-7-13-31(49-41(62)32(48-26(3)56)15-16-38(58)59)40(61)46-22-37(57)54-17-8-14-36(54)44(65)51-34(42(63)52-35)20-28-11-6-10-27-9-4-5-12-30(27)28/h4-6,9-12,21,25,31-36H,7-8,13-20,22-24H2,1-3H3,(H2,45,60)(H,46,61)(H,48,56)(H,49,62)(H,50,64)(H,51,65)(H,52,63)(H,58,59)/t31-,32-,33-,34-,35+,36-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B22023450&gt;</td>
#     </tr>
#     <tr>
#       <th>490</th>
#       <td>CHEMBL5091680</td>
#       <td>CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(=O)N2CC[C@@H](O)[C@H]2C(=O)N[C@@H](Cc2cccc3ccccc23)C(=O)N1)C(N)=O</td>
#       <td>4.160</td>
#       <td>InChI=1S/C37H49N9O8/c1-22(2)16-27(34(38)50)41-36(52)29-21-54-20-25-18-40-44-46(25)14-6-5-12-31(48)39-19-32(49)45-15-13-30(47)33(45)37(53)42-28(35(51)43-29)17-24-10-7-9-23-8-3-4-11-26(23)24/h3-4,7-11,18,22,27-30,33,47H,5-6,12-17,19-21H2,1-2H3,(H2,38,50)(H,39,48)(H,41,52)(H,42,53)(H,43,51)/t27-,28-,29-,30+,33-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B22020270&gt;</td>
#     </tr>
#     <tr>
#       <th>484</th>
#       <td>CHEMBL5080225</td>
#       <td>CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(=O)N2CCC[C@H]2C(=O)N[C@@H](Cc2cccs2)C(=O)N1)C(N)=O</td>
#       <td>4.275</td>
#       <td>InChI=1S/C31H45N9O7S/c1-19(2)13-22(28(32)43)35-30(45)24-18-47-17-20-15-34-38-40(20)11-4-3-9-26(41)33-16-27(42)39-10-5-8-25(39)31(46)36-23(29(44)37-24)14-21-7-6-12-48-21/h6-7,12,15,19,22-25H,3-5,8-11,13-14,16-18H2,1-2H3,(H2,32,43)(H,33,41)(H,35,45)(H,36,46)(H,37,44)/t22-,23-,24-,25-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B22021150&gt;</td>
#     </tr>
#   </tbody>
# </table>

# %%
PandasTools.WriteSDF(data_test, 'KRAS_test.sdf', molColName='Molecule', properties=list(data.columns))

# %% [markdown]
# Creating work set

# %%
PandasTools.AddMoleculeColumnToFrame(data_work, 'canonical_smiles', 'Molecule')

# %%
HTML(data_work.head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>molecule_chembl_id</th>
#       <th>canonical_smiles</th>
#       <th>pchembl_value_mean</th>
#       <th>inchi</th>
#       <th>Molecule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>497</th>
#       <td>CHEMBL5082248</td>
#       <td>NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(=O)N2CCC[C@H]2C(=O)N[C@@H](Cc2cccc3ccccc23)C(=O)N1</td>
#       <td>4.0</td>
#       <td>InChI=1S/C40H53N9O7/c41-37(52)31(20-26-10-2-1-3-11-26)44-39(54)33-25-56-24-29-22-43-47-49(29)19-7-6-17-35(50)42-23-36(51)48-18-9-16-34(48)40(55)45-32(38(53)46-33)21-28-14-8-13-27-12-4-5-15-30(27)28/h4-5,8,12-15,22,26,31-34H,1-3,6-7,9-11,16-21,23-25H2,(H2,41,52)(H,42,50)(H,44,54)(H,45,55)(H,46,53)/t31-,32-,33-,34-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B220A7A70&gt;</td>
#     </tr>
#     <tr>
#       <th>498</th>
#       <td>CHEMBL5079991</td>
#       <td>CCCC[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(=O)N2CCC[C@H]2C(=O)N[C@@H](Cc2cccc3ccccc23)C(=O)N1)C(N)=O</td>
#       <td>4.0</td>
#       <td>InChI=1S/C37H49N9O7/c1-2-3-14-28(34(38)49)41-36(51)30-23-53-22-26-20-40-44-46(26)18-7-6-16-32(47)39-21-33(48)45-17-9-15-31(45)37(52)42-29(35(50)43-30)19-25-12-8-11-24-10-4-5-13-27(24)25/h4-5,8,10-13,20,28-31H,2-3,6-7,9,14-19,21-23H2,1H3,(H2,38,49)(H,39,47)(H,41,51)(H,42,52)(H,43,50)/t28-,29-,30-,31-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B220A5230&gt;</td>
#     </tr>
#     <tr>
#       <th>492</th>
#       <td>CHEMBL5082312</td>
#       <td>CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(=O)N(C)[C@@H](C(C)C)C(=O)N[C@@H](Cc2cccc3ccccc23)C(=O)N1)C(N)=O</td>
#       <td>4.0</td>
#       <td>InChI=1S/C38H53N9O7/c1-23(2)17-29(35(39)50)42-37(52)31-22-54-21-27-19-41-45-47(27)16-9-8-15-32(48)40-20-33(49)46(5)34(24(3)4)38(53)43-30(36(51)44-31)18-26-13-10-12-25-11-6-7-14-28(25)26/h6-7,10-14,19,23-24,29-31,34H,8-9,15-18,20-22H2,1-5H3,(H2,39,50)(H,40,48)(H,42,52)(H,43,53)(H,44,51)/t29-,30-,31-,34-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B220A4A50&gt;</td>
#     </tr>
#     <tr>
#       <th>476</th>
#       <td>CHEMBL5083076</td>
#       <td>CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)NCC(=O)N2CCC[C@H]2C(=O)N[C@@H](CC2CCCCC2)C(=O)N1)C(N)=O</td>
#       <td>4.0</td>
#       <td>InChI=1S/C33H53N9O7/c1-21(2)15-24(30(34)45)37-32(47)26-20-49-19-23-17-36-40-42(23)14-7-6-12-28(43)35-18-29(44)41-13-8-11-27(41)33(48)38-25(31(46)39-26)16-22-9-4-3-5-10-22/h17,21-22,24-27H,3-16,18-20H2,1-2H3,(H2,34,45)(H,35,43)(H,37,47)(H,38,48)(H,39,46)/t24-,25-,26-,27-/m0/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B220A7ED0&gt;</td>
#     </tr>
#     <tr>
#       <th>508</th>
#       <td>CHEMBL5078080</td>
#       <td>CC(C)C[C@H](NC(=O)[C@@H]1COCc2cnnn2CCCCC(=O)N[C@H](CCC(=O)O)C(=O)N2CCC[C@H]2C(=O)N[C@@H](Cc2cccc3ccccc23)C(=O)N1)C(N)=O</td>
#       <td>4.0</td>
#       <td>InChI=1S/C40H53N9O9/c1-24(2)19-30(36(41)53)44-38(55)32-23-58-22-27-21-42-47-49(27)18-6-5-14-34(50)43-29(15-16-35(51)52)40(57)48-17-8-13-33(48)39(56)45-31(37(54)46-32)20-26-11-7-10-25-9-3-4-12-28(25)26/h3-4,7,9-12,21,24,29-33H,5-6,8,13-20,22-23H2,1-2H3,(H2,41,53)(H,43,50)(H,44,55)(H,45,56)(H,46,54)(H,51,52)/t29-,30+,31+,32+,33+/m1/s1</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x0000026B220A4890&gt;</td>
#     </tr>
#   </tbody>
# </table>

# %%
PandasTools.WriteSDF(data_work, 'KRAS_work.sdf', molColName='Molecule', properties=list(data.columns))
